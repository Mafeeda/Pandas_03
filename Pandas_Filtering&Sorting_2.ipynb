# %% [markdown]
# ## Filtering and Sorting

# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
item_data = pd.read_csv('data.tsv.txt', sep = '\t')
item_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Initial Analysis

# %%
item_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
item_data.shape
# Out:
# (4622, 5)

# %%
item_data.describe(include = 'all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
item_data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
# Clean the item_price and make it for model training

# %%
item_data['cleaned_item_price'] = item_data['item_price'].str.replace('$','').astype(float)
item_data
# Out:
# <ipython-input-9-ecaa594a5092>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   item_data['cleaned_item_price'] = item_data['item_price'].str.replace('$','').astype(float)
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# ...

# %%
item_data.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price             object
# cleaned_item_price    float64
# dtype: object

# %%
del item_data['item_price']

# %%
item_data.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
# Get Chicken salad bowl complete details

# %%
chicken_salad_details = item_data[item_data['item_name'] == 'Chicken Salad Bowl']
chicken_salad_details
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 135         60         2  Chicken Salad Bowl
# 213         94         2  Chicken Salad Bowl
# 256        111         1  Chicken Salad Bowl
# 315        137         2  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4561      1813         2  Chicken Salad Bowl
# 4580      1822         1  Chicken Salad Bowl
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  cleaned_item_price
# 44    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...                8.75
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...               22.50
# 213   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...               22.50
# 256   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...                8.75
# ...

# %%
pd.set_option('max_rows',None)

# %%
chicken_salad_details.shape
# Out:
# (110, 5)

# %%
# Select the item Chicken salad bowl where quantity is equal to 1.

# %%
item_data[(item_data['item_name'] == 'Chicken Salad Bowl') & (item_data['quantity'] == 1)]
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 256        111         1  Chicken Salad Bowl
# 526        220         1  Chicken Salad Bowl
# 528        221         1  Chicken Salad Bowl
# 529        221         1  Chicken Salad Bowl
# 568        234         1  Chicken Salad Bowl
# 585        240         1  Chicken Salad Bowl
# 693        286         1  Chicken Salad Bowl
# 702        289         1  Chicken Salad Bowl
# 762        314         1  Chicken Salad Bowl
# 1109       458         1  Chicken Salad Bowl
# 1189       488         1  Chicken Salad Bowl
# 1352       552         1  Chicken Salad Bowl
# 1422       577         1  Chicken Salad Bowl
# 1460       592         1  Chicken Salad Bowl
# 1471       598         1  Chicken Salad Bowl
# 1483       602         1  Chicken Salad Bowl
# 1524       621         1  Chicken Salad Bowl
# 1547       628         1  Chicken Salad Bowl
# 1601       649         1  Chicken Salad Bowl
# ...

# %%
# Display the items from most expensive to less expensive.

# %%
item_price_details = item_data[['item_name','cleaned_item_price']]
item_price_details
# Out:
#                                   item_name  cleaned_item_price
# 0              Chips and Fresh Tomato Salsa                2.39
# 1                                      Izze                3.39
# 2                          Nantucket Nectar                3.39
# 3     Chips and Tomatillo-Green Chili Salsa                2.39
# 4                              Chicken Bowl               16.98
# 5                              Chicken Bowl               10.98
# 6                             Side of Chips                1.69
# 7                             Steak Burrito               11.75
# 8                          Steak Soft Tacos                9.25
# 9                             Steak Burrito                9.25
# 10                      Chips and Guacamole                4.45
# 11                     Chicken Crispy Tacos                8.75
# 12                       Chicken Soft Tacos                8.75
# 13                             Chicken Bowl               11.25
# ...
