# %% [markdown]
# ## Filtering & Sorting

# %%
## Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
euro_2012_data = pd.read_csv('Euro_2012_stats_TEAM.csv')
euro_2012_data.head(10)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# ...

# %%
euro_2012_data.shape
# Out:
# (16, 35)

# %%
euro_2012_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
# How many teams participated in euro_worldcup_2012

# %%
euro_2012_data.Team.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object>

# %%
euro_2012_data.Team.nunique()
# Out:
# 16

# %%
euro_2012_data.Team.unique()
# Out:
# array(['Croatia', 'Czech Republic', 'Denmark', 'England', 'France',
#        'Germany', 'Greece', 'Italy', 'Netherlands', 'Poland', 'Portugal',
#        'Republic of Ireland', 'Russia', 'Spain', 'Sweden', 'Ukraine'],
#       dtype=object)

# %%
# View dataset with Teams,Yellow and Red cards

# %%
team_red_yellow_card = euro_2012_data[['Team','Yellow Cards','Red Cards']]
team_red_yellow_card
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Sort the team by red card

# %%
team_red_yellow_card.sort_values(by = 'Red Cards', ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 10             Portugal            12          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# On an average , a team is getting how many yellow cards

# %%
team_red_yellow_card['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
round(team_red_yellow_card['Yellow Cards'].mean())
# Out:
# 7

# %%
# Filter the team who scored more than 8 goals

# %%
euro_2012_data[euro_2012_data.Goals>8]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# Get the team names starting with letter 's'

# %%
euro_2012_data[euro_2012_data.Team.str.startswith('S')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 13   Spain     12               42                33             55.9%
# 14  Sweden      5               17                19             47.2%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 13            16.0%                         100             0              1
# 14            13.8%                          39             3              0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 13                     0  ...          15                 93.8%        102
# 14                     0  ...           8                 61.6%         35
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 13             83        19            11          0       17        17
# 14             51         7             7          0        9         9
#
#     Players Used
# 13            18
# 14            18
#
# ...

# %%
# Get the first 7 records of first 5 columns

# %%
euro_2012_data.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %%
## Index Locater

# %%
euro_2012_data.iloc[0:8 , 0:6]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
#
#   % Goals-to-shots
# 0            16.0%
# 1            12.9%
# 2            20.0%
# 3            17.2%
# 4             6.5%
# 5            15.6%
# 6            19.2%
# 7             7.5%

# %%
#enumerate - will return 2 values - column index and your column name
for index_no,column_name in enumerate(euro_2012_data):
    print(index_no, column_name)
# Out:
# 0 Team
# 1 Goals
# 2 Shots on target
# 3 Shots off target
# 4 Shooting Accuracy
# 5 % Goals-to-shots
# 6 Total shots (inc. Blocked)
# 7 Hit Woodwork
# 8 Penalty goals
# 9 Penalties not scored
# 10 Headed goals
# 11 Passes
# 12 Passes completed
# 13 Passing Accuracy
# 14 Touches
# 15 Crosses
# 16 Dribbles
# 17 Corners Taken
# 18 Tackles
# 19 Clearances
# 20 Interceptions
# 21 Clearances off line
# 22 Clean Sheets
# 23 Blocks
# 24 Goals conceded
# 25 Saves made
# 26 Saves-to-shots ratio
# 27 Fouls Won
# 28 Fouls Conceded
# 29 Offsides
# 30 Yellow Cards
# 31 Red Cards
# 32 Subs on
# 33 Subs off
# 34 Players Used

# %%
df = euro_2012_data[['Yellow Cards','Red Cards','Shooting Accuracy']]

# %%
df
# Out:
#     Yellow Cards  Red Cards Shooting Accuracy
# 0              9          0             51.9%
# 1              7          0             41.9%
# 2              4          0             50.0%
# 3              5          0             50.0%
# 4              6          0             37.9%
# 5              4          0             47.8%
# 6              9          1             30.7%
# 7             16          0             43.0%
# 8              5          0             25.0%
# 9              7          1             39.4%
# 10            12          0             34.3%
# 11             6          1             36.8%
# 12             6          0             22.5%
# 13            11          0             55.9%
# 14             7          0             47.2%
# 15             5          0             21.2%

# %%
euro_2012_data.iloc[:,30:32]
# Out:
#     Yellow Cards  Red Cards
# 0              9          0
# 1              7          0
# 2              4          0
# 3              5          0
# 4              6          0
# 5              4          0
# 6              9          1
# 7             16          0
# 8              5          0
# 9              7          1
# 10            12          0
# 11             6          1
# 12             6          0
# 13            11          0
# 14             7          0
# 15             5          0

# %%
#loc 
euro_2012_data.loc[:7,'Yellow Cards':'Red Cards']
# Out:
#    Yellow Cards  Red Cards
# 0             9          0
# 1             7          0
# 2             4          0
# 3             5          0
# 4             6          0
# 5             4          0
# 6             9          1
# 7            16          0

# %%
# Display the Shooting Accuracy of Denmark ,France and Greece

# %%
## filtering using set_index

# %%
euro_2012_data.set_index('Team' , inplace = True)

# %%
euro_2012_data
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
euro_2012_data.loc[['Denmark','France','France'],['Shooting Accuracy']]
# Out:
#         Shooting Accuracy
# Team
# Denmark             50.0%
# France              37.9%
# France              37.9%
